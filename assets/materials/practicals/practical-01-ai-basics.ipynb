# %% [markdown]
# # 1-практика: ЖИ негіздері
#
# Бұл notebook файлын алғашқы ЖИ практикалық тапсырмаңызға бастапқы үлгі ретінде қолданыңыз.

# %%
print("Жасанды интеллект негіздері курсына қош келдіңіз")
